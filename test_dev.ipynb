# %%
import h5py
import utils

# %%
with h5py.File("./datasets/cached/div2k-x4_0_64.hdf5") as f:
    # corresponds with div2k images 0001 - 00016
    utils.showImages(f["hr"][0:8])
    utils.showImages(f["hr"][8:16])

# %%
with h5py.File("./datasets/cached/div2k-x4_1_64.hdf5") as f:
    # corresponds with div2k images 0017 - 0032
    utils.showImages(f["hr"][0:8])
    utils.showImages(f["hr"][8:16])
