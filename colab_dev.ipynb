# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive/AP Research/autoreg-sr'

import os
from getpass import getpass
user = getpass('GitHub user')
password = getpass('GitHub password')
os.environ['GITHUB_AUTH'] = user + ':' + password
! git config --global user.email "you@example.com"
  git config --global user.name "Your Name"
# !git add colab_dev.ipynb
# !git commit
# !git push
# Out:
# /content/gdrive/MyDrive/AP Research/autoreg-sr
# GitHub user··········
# GitHub password··········
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@2632df327098.(none)')
# Everything up-to-date

# %%
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@2632df327098.(none)')
# Everything up-to-date

# %%
# !ls
# Out:
# '50 Sources.gdoc'
#  annotatedbib.txt
# 'AP Research Annotated Bib Final 20 - Zacharu Huang.gdoc'
# 'AP Research Annotated Bibliography Part 1 Zachary Huang.gdoc'
# 'AP Research Annotated Bibliography Part 2 Zachary Huang.gdoc'
# 'AP Research PREP Zack.gsite'
# 'AP Research Reflection Journal 2020.gdoc'
# 'AP Research Rubric Grade.gdoc'
#  autoreg-sr
# 'copy of All 50 Sources.gdoc'
# 'Copy of AP Research Reflection Journal 2020 Week 1.gdoc'
# 'Elevator Speech.gdoc'
# 'First 25 sources Zack.gdoc'
# 'Important Links.gdoc'
# 'Inquiry Proposal Form Final - Zachary  Huang.gdoc'
# 'Inquiry Proposal Form - Zachary  Huang.gdoc'
# 'ISEF Forms 2021 Zachary Huang.pdf'
# 'Materials List.gdoc'
# 'Model Comparisons.gdoc'
# 'Poster Stage 1,2.gslides'
#  project_code
# 'Research Plan Project Summary 2020.gdoc'
#  Timeline.gdoc
# 'Zack Milestone 1-2020.gdoc'
#  ZHuangIntro1121.gdoc
#  ZHuangIntro1130.gdoc
