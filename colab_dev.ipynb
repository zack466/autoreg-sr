# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/AP Research/autoreg-sr'

# get latest changes from repo
import os
from getpass import getpass
user = getpass('GitHub user')
password = getpass('GitHub password')
os.environ['GITHUB_AUTH'] = user + ':' + password
# !git config --global user.email "zack466@gmail.com"
# !git config --global user.name "Zachary Huang"
# !git pull
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/AP Research/autoreg-sr
# GitHub user··········
# GitHub password··········
# Already up to date.

# %%
# !pip install torch torchvision

# %%
# don't forget to set runtime to gpu
import torch
import torchvision
from models import SRCNN

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
srcnn = SRCNN().to(device)
a = torch.rand((16, 3, 64, 64)).to(device)
srcnn(a)
# Out:
# tensor([[[[3.3685e-02, 4.3487e-02, 2.3873e-02,  ..., 3.3139e-02,
#            4.4378e-02, 3.5425e-02],
#           [2.8357e-03, 0.0000e+00, 2.4314e-02,  ..., 4.0360e-02,
#            5.1093e-02, 5.3687e-02],
#           [0.0000e+00, 1.4081e-03, 0.0000e+00,  ..., 5.0609e-03,
#            3.6988e-02, 7.0539e-02],
#           ...,
#           [0.0000e+00, 1.1141e-02, 1.9450e-02,  ..., 3.0581e-02,
#            1.0734e-02, 1.7553e-02],
#           [4.4226e-03, 0.0000e+00, 0.0000e+00,  ..., 4.0569e-02,
#            1.3718e-02, 7.0991e-03],
#           [0.0000e+00, 0.0000e+00, 7.1645e-05,  ..., 2.2385e-02,
#            0.0000e+00, 0.0000e+00]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            2.1519e-02, 1.2401e-02],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            4.0876e-03, 4.6235e-03],
#           [3.0093e-03, 9.1300e-03, 0.0000e+00,  ..., 0.0000e+00,
#            3.4877e-02, 1.5226e-02],
#           ...,
# ...

# %%
# !git add *
# !git status
#!git commit -m "testing colab environment"
#!git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   colab_dev.ipynb
# 	new file:   models/__pycache__/__init__.cpython-36.pyc
# 	new file:   models/__pycache__/srcnn.cpython-36.pyc
